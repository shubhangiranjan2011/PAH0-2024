# %%
# !pip install openpyxl
import openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
data = pd.read_excel('/content/PERCardio Feb22.xlsx')
data
# Out:
#           Búsqueda por Proveedor      Unnamed: 1 Unnamed: 2  \
# 0                            NaN             NaN        NaN
# 1                            NaN             NaN        NaN
# 2                    RazonSocial  Código Entidad    Entidad
# 3                     ALBIS S.A.               1      MINSA
# 4                     ALBIS S.A.               1      MINSA
# ...                          ...             ...        ...
# 3261  LABORATORIOS AMERICANOS SA               1      MINSA
# 3262  LABORATORIOS AMERICANOS SA               1      MINSA
# 3263  LABORATORIOS AMERICANOS SA               1      MINSA
# 3264  LABORATORIOS AMERICANOS SA               1      MINSA
# 3265  LABORATORIOS AMERICANOS SA               1      MINSA
#
#               Unnamed: 3       Unnamed: 4               Unnamed: 5  \
# 0                    NaN              NaN                      NaN
# 1                    NaN              NaN                      NaN
# 2     Código Disa/Diresa  Establecimiento  Código Unidad Ejecutora
# 3                      2    DIRESA ANCASH                      002
# 4                      4  GERESA AREQUIPA                     1657
# ...                  ...              ...                      ...
# 3261                   4  GERESA AREQUIPA                     1657
# 3262                  11     DIRESA CUSCO                     1626
# 3263                  11     DIRESA CUSCO                     1625
# 3264                  32     DIRESA TACNA                     1622
# 3265                  17     DIRESA JUNIN                        0
#
#                                              Unnamed: 6  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                      Punto de Entrega
# 3                    DIRECCIÓN REGIONAL DE SALUD ANCASH
# 4     GERENCIA REGIONAL DE SALUD DEL GOBIERNO REGION...
# ...                                                 ...
# 3261  HOSPITAL CENTRAL DE MAJES “ING. ANGEL GABRIEL ...
# 3262       UNIDAD EJECUTORA 410 HOSPITAL DE QUILLABAMBA
# 3263  UNIDAD EJECUTORA 409 - HOSPITAL ALFREDO CALLO ...
# 3264                                 RED DE SALUD TACNA
# 3265  HOSPITAL REGIONAL DOCENTE DE MEDICINA TROPICAL...
#
#                   Unnamed: 7       Unnamed: 8                   Unnamed: 9  \
# 0                        NaN              NaN                          NaN
# 1                        NaN              NaN                          NaN
# 2     Identificación Proceso  Código Producto                     Producto
# 3          LP SIP N 12  2012            04523           LOSARTAN 50 MG TAB
# 4          LP SIP N 12  2012            04523           LOSARTAN 50 MG TAB
# ...                      ...              ...                          ...
# 3261      SIE SIP N 13  2020            03921  HIDROCLOROTIAZIDA 25 MG TAB
# 3262      SIE SIP N 13  2020            03921  HIDROCLOROTIAZIDA 25 MG TAB
# 3263      SIE SIP N 13  2020            03921  HIDROCLOROTIAZIDA 25 MG TAB
# 3264      SIE SIP N 13  2020            03921  HIDROCLOROTIAZIDA 25 MG TAB
# 3265      SIE SIP N 13  2020            03921  HIDROCLOROTIAZIDA 25 MG TAB
#
#      Unnamed: 10                  Unnamed: 11              Unnamed: 12  \
# 0            NaN                          NaN                      NaN
# 1            NaN                          NaN                      NaN
# 2       Cantidad  Precio Unitario Referencial  Monto Total Referencial
# 3           6000                       0.0328                    196.8
# 4          10000                       0.0328                      328
# ...          ...                          ...                      ...
# 3261       10000                       0.0256                      256
# 3262       20000                       0.0256                      512
# 3263        2500                       0.0256                       64
# 3264       20000                       0.0256                      512
# 3265        5000                       0.0256                      128
#
#                    Unnamed: 13           Unnamed: 14 Unnamed: 15
# 0                          NaN                   NaN         NaN
# 1                          NaN                   NaN         NaN
# 2     Precio Unitario Ofertado  Monto Total Ofertado        Pais
# 3                     0.030572            183.431975         NaN
# 4                     0.030572            305.719959         NaN
# ...                        ...                   ...         ...
# 3261                  0.027083            270.832737         NaN
# 3262                  0.027083            541.665474         NaN
# 3263                  0.027083             67.708184         NaN
# 3264                  0.027083            541.665474         NaN
# 3265                  0.027083            135.416368         NaN
#
# [3266 rows x 16 columns]

# %%
rawdrugnames =  data[data.columns[9]]
rawdrugnames.tolist()
rawdrugnames
# Out:
# 0                               NaN
# 1                               NaN
# 2                          Producto
# 3                LOSARTAN 50 MG TAB
# 4                LOSARTAN 50 MG TAB
#                    ...
# 3261    HIDROCLOROTIAZIDA 25 MG TAB
# 3262    HIDROCLOROTIAZIDA 25 MG TAB
# 3263    HIDROCLOROTIAZIDA 25 MG TAB
# 3264    HIDROCLOROTIAZIDA 25 MG TAB
# 3265    HIDROCLOROTIAZIDA 25 MG TAB
# Name: Unnamed: 9, Length: 3266, dtype: object

# %%
pip install mtranslate==1.8
# Out:
# Collecting mtranslate==1.8
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3672 sha256=20b0e4d1cfc19a208f4ce4e9d30760542f1eddfee63f93f6ec905dab5343535e
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
from mtranslate import translate

def translate_text(text):
    if isinstance(text, str):
        try:
            # Encode text to bytes before translation
            text_bytes = text.encode('utf-8')
            translated = translate(text_bytes, 'en', 'auto')
            return translated
        except Exception as e:
            print(f"Translation failed: {e}")
            return "Translation failed"
    else:
        return ""


translated_texts = []
for text in rawdrugnames:
    translated_texts.append(translate_text(text))
print(translated_texts)
# Out:
# ['', '', 'Product', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'LOSARTAN 50 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE 25 MG TAB', 'HYDROCHLOROTHIAZIDE ...

# %%
translated_texts
# Out:
# ['',
#  '',
#  'Product',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'LOSARTAN 50 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE (COMO BESYLATO) 5 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'AMLODIPINE 10 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  'HYDROCHLOROTHIAZIDE 25 MG TAB',
#  ...]

# %%
drug_names = []
concentrations = []


for row in translated_texts[3:]:
  # Find the first index of a numeric character
  first_numeric_index = next((i for i, char in enumerate(row) if char.isdigit()), None)

  # Check if there are numeric characters
  if first_numeric_index is not None:
    # Extract drug name based on the index
    drug_name = row[:first_numeric_index]
    # Extract composition including numeric characters
    composition = row[first_numeric_index:]


    # Append the extracted values to the lists
    drug_names.append(drug_name)
    concentrations.append(composition)

# Create DataFrame
df = pd.DataFrame({ 'Drug Original Name': drug_names,
    'Concentration': concentrations
})

print(df)
# Out:
#         Drug Original Name Concentration
# 0                LOSARTAN      50 MG TAB
# 1                LOSARTAN      50 MG TAB
# 2                LOSARTAN      50 MG TAB
# 3                LOSARTAN      50 MG TAB
# 4                LOSARTAN      50 MG TAB
# ...                    ...           ...
# 3258  HYDROCHLOROTHIAZIDE      25 MG TAB
# 3259  HYDROCHLOROTHIAZIDE      25 MG TAB
# 3260  HYDROCHLOROTHIAZIDE      25 MG TAB
# 3261  HYDROCHLOROTHIAZIDE      25 MG TAB
# 3262  HYDROCHLOROTHIAZIDE      25 MG TAB
#
# [3263 rows x 2 columns]

# %%
df.to_csv('PERCardio Feb22-cleaned.csv')
