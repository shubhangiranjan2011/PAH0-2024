# %%
import pandas as pd
data = pd.read_csv('/content/BRACardio1.csv')
data
# Out:
#       Base de dados BPS                    Unnamed: 1  \
# 0         Dados do Item                           NaN
# 1             Código BR              Descrição CATMAT
# 2             BR0267565   CARVEDILOL, DOSAGEM:6,25 MG
# 3             BR0267566  CARVEDILOL, DOSAGEM:3,125 MG
# 4             BR0267564   CARVEDILOL, DOSAGEM:12,5 MG
# ..                  ...                           ...
# 952           BR0267566  CARVEDILOL, DOSAGEM:3,125 MG
# 953           BR0267565   CARVEDILOL, DOSAGEM:6,25 MG
# 954           BR0267564   CARVEDILOL, DOSAGEM:12,5 MG
# 955           BR0267567     CARVEDILOL, DOSAGEM:25 MG
# 956           BR0267565   CARVEDILOL, DOSAGEM:6,25 MG
#
#                     Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0                          NaN        NaN  Dados da Compra            NaN
# 1     Unidade de Fornecimento    Genérico  Registro Anvisa   Data Compra
# 2        COMPRIMIDO - GENÉRICO        Sim    1058308410073     11/10/2021
# 3        COMPRIMIDO - GENÉRICO        Sim    1058308410022     11/10/2021
# 4        COMPRIMIDO - GENÉRICO        Sim    1058308410121     11/10/2021
# ..                         ...        ...              ...            ...
# 952      COMPRIMIDO - GENÉRICO        Sim    1023510730048     03/05/2021
# 953      COMPRIMIDO - GENÉRICO        Sim    1023510730110     03/05/2021
# 954      COMPRIMIDO - GENÉRICO        Sim    1023510730188     03/05/2021
# 955      COMPRIMIDO - GENÉRICO        Sim    1023510730250     03/05/2021
# 956      COMPRIMIDO - GENÉRICO        Sim    1267502420064     27/10/2021
#
#                Unnamed: 6      Unnamed: 7   Unnamed: 8  \
# 0                     NaN             NaN          NaN
# 1    Modalidade da Compra   Data Inserção  Tipo Compra
# 2                  Pregão      22/11/2021            A
# 3                  Pregão      22/11/2021            A
# 4                  Pregão      22/11/2021            A
# ..                    ...             ...          ...
# 952                Pregão      12/05/2021            A
# 953                Pregão      12/05/2021            A
# 954                Pregão      12/05/2021            A
# 955                Pregão      12/05/2021            A
# 956                Pregão      08/12/2021            A
#
#                           Unnamed: 9  ...         Unnamed: 12  \
# 0     Dados do Fabricante Fornecedor  ...                 NaN
# 1                         Fabricante  ...     CNPJ Fornecedor
# 2           GERMED FARMACÊUTICA LTDA  ...  11.195.977/0001-28
# 3           GERMED FARMACÊUTICA LTDA  ...  11.195.977/0001-28
# 4           GERMED FARMACÊUTICA LTDA  ...  11.195.977/0001-28
# ..                               ...  ...                 ...
# 952                          EMS S/A  ...  28.093.678/0001-85
# 953                          EMS S/A  ...  28.093.678/0001-85
# 954                          EMS S/A  ...  28.093.678/0001-85
# 955                          EMS S/A  ...  28.093.678/0001-85
# 956  NOVA QUIMICA FARMACEUTICA LTDA   ...  20.590.555/0001-48
#
#                                      Unnamed: 13         Unnamed: 14  \
# 0                           Dados da Instituição                 NaN
# 1                               Nome Instituição    CNPJ Instituição
# 2                       FUNDO MUNICIPAL DE SAUDE  11.594.727/0001-60
# 3                       FUNDO MUNICIPAL DE SAUDE  11.594.727/0001-60
# 4                       FUNDO MUNICIPAL DE SAUDE  11.594.727/0001-60
# ..                                           ...                 ...
# 952   FUNDO MUNICIPAL DE SAUDE DE CASSILANDIA-MS  14.540.893/0001-72
# 953   FUNDO MUNICIPAL DE SAUDE DE CASSILANDIA-MS  14.540.893/0001-72
# 954   FUNDO MUNICIPAL DE SAUDE DE CASSILANDIA-MS  14.540.893/0001-72
# 955   FUNDO MUNICIPAL DE SAUDE DE CASSILANDIA-MS  14.540.893/0001-72
# 956  FUNDACAO MUNICIPAL DE SAUDE DE PONTA GROSSA  32.370.759/0001-52
#
#                Unnamed: 15 Unnamed: 16          Unnamed: 17     Unnamed: 18  \
# 0                      NaN         NaN              Valores             NaN
# 1    Município Instituição          UF  Qtd Itens Comprados  Preço Unitário
# 2             MAR VERMELHO          AL           25000,0000          0,0010
# 3             MAR VERMELHO          AL           16000,0000          0,0010
# 4             MAR VERMELHO          AL           25000,0000          0,0015
# ..                     ...         ...                  ...             ...
# 952            CASSILANDIA          MS           15000,0000        135,0000
# 953            CASSILANDIA          MS           20000,0000        140,0000
# 954            CASSILANDIA          MS           20000,0000        145,0000
# 955            CASSILANDIA          MS           20000,0000        200,0000
# 956           PONTA GROSSA          PR          563000,0000        930,0000
#
#                Unnamed: 19       Unnamed: 20        Unnamed: 21
# 0                      NaN               NaN                NaN
# 1    CMED - Preço Regulado  Competência CMED   Média Ponderada
# 2                   2,3623           02/2022             0,0942
# 3                   2,1033           02/2022             0,0884
# 4                   2,6307           02/2022             0,1095
# ..                     ...               ...                ...
# 952                 2,1033           02/2022             0,0884
# 953                 2,3623           02/2022             0,0942
# 954                 2,6307           02/2022             0,1095
# 955                 2,9490           02/2022             0,1600
# 956                 2,3913           02/2022             0,0942
#
# [957 rows x 22 columns]

# %%
rawdrugnames =  data[data.columns[1]]
rawdrugnames.tolist()
rawdrugnames
# Out:
# 0                               NaN
# 1                  Descrição CATMAT
# 2       CARVEDILOL, DOSAGEM:6,25 MG
# 3      CARVEDILOL, DOSAGEM:3,125 MG
# 4       CARVEDILOL, DOSAGEM:12,5 MG
#                    ...
# 952    CARVEDILOL, DOSAGEM:3,125 MG
# 953     CARVEDILOL, DOSAGEM:6,25 MG
# 954     CARVEDILOL, DOSAGEM:12,5 MG
# 955       CARVEDILOL, DOSAGEM:25 MG
# 956     CARVEDILOL, DOSAGEM:6,25 MG
# Name: Unnamed: 1, Length: 957, dtype: object

# %%
rawdrugnames[600:650]
# Out:
# 600        CARVEDILOL, DOSAGEM:25 MG
# 601      CLORTALIDONA, DOSAGEM:25 MG
# 602       CLOPIDOGREL, DOSAGEM:75 MG
# 603      CARVEDILOL, DOSAGEM:6,25 MG
# 604      CARVEDILOL, DOSAGEM:12,5 MG
# 605        CARVEDILOL, DOSAGEM:25 MG
# 606     CARVEDILOL, DOSAGEM:3,125 MG
# 607     CARVEDILOL, DOSAGEM:3,125 MG
# 608       CLOPIDOGREL, DOSAGEM:75 MG
# 609        CARVEDILOL, DOSAGEM:25 MG
# 610      CLORTALIDONA, DOSAGEM:25 MG
# 611      CLORTALIDONA, DOSAGEM:50 MG
# 612      CLORTALIDONA, DOSAGEM:50 MG
# 613        CARVEDILOL, DOSAGEM:25 MG
# 614     CARVEDILOL, DOSAGEM:3,125 MG
# 615        CARVEDILOL, DOSAGEM:25 MG
# 616      CARVEDILOL, DOSAGEM:6,25 MG
# 617      CARVEDILOL, DOSAGEM:6,25 MG
# 618      CLORTALIDONA, DOSAGEM:50 MG
# 619      CLORTALIDONA, DOSAGEM:25 MG
# 620       CLOPIDOGREL, DOSAGEM:75 MG
# 621        CARVEDILOL, DOSAGEM:25 MG
# 622       CLOPIDOGREL, DOSAGEM:75 MG
# 623       CLOPIDOGREL, DOSAGEM:75 MG
# 624     CARVEDILOL, DOSAGEM:3,125 MG
# 625      CARVEDILOL, DOSAGEM:6,25 MG
# 626      CLORTALIDONA, DOSAGEM:50 MG
# 627        CARVEDILOL, DOSAGEM:25 MG
# 628      CARVEDILOL, DOSAGEM:12,5 MG
# 629      CLORTALIDONA, DOSAGEM:25 MG
# 630       CLOPIDOGREL, DOSAGEM:75 MG
# 631      CLORTALIDONA, DOSAGEM:50 MG
# 632        CARVEDILOL, DOSAGEM:25 MG
# 633        CARVEDILOL, DOSAGEM:25 MG
# 634    CLORTALIDONA, DOSAGEM:12,5 MG
# 635       CLOPIDOGREL, DOSAGEM:75 MG
# 636      CLORTALIDONA, DOSAGEM:25 MG
# 637        CARVEDILOL, DOSAGEM:25 MG
# 638        CARVEDILOL, DOSAGEM:25 MG
# 639      CARVEDILOL, DOSAGEM:12,5 MG
# 640       CLOPIDOGREL, DOSAGEM:75 MG
# 641      CARVEDILOL, DOSAGEM:6,25 MG
# 642      CARVEDILOL, DOSAGEM:12,5 MG
# 643       CLOPIDOGREL, DOSAGEM:75 MG
# 644       CLOPIDOGREL, DOSAGEM:75 MG
# 645       CLOPIDOGREL, DOSAGEM:75 MG
# 646       CLOPIDOGREL, DOSAGEM:75 MG
# 647       CLOPIDOGREL, DOSAGEM:75 MG
# 648        CARVEDILOL, DOSAGEM:25 MG
# 649       CLOPIDOGREL, DOSAGEM:75 MG
# Name: Unnamed: 1, dtype: object

# %%
pip install mtranslate==1.8
# Out:
# Collecting mtranslate==1.8
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3672 sha256=b1a2e1602bd9967672fbf6dc096f1d3a765086a21adadd52ae85f157ce166b74
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
from mtranslate import translate

def translate_text(text):
    if isinstance(text, str):
        try:
            # Encode text to bytes before translation
            text_bytes = text.encode('utf-8')
            translated = translate(text_bytes, 'en', 'auto')
            return translated
        except Exception as e:
            print(f"Translation failed: {e}")
            return "Translation failed"
    else:
        return ""


translated_texts = []
for text in rawdrugnames:
    translated_texts.append(translate_text(text))
print(translated_texts)
# Out:
# ['', 'Description\xa0CATMAT', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:12,5 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:12,5 MG', 'CLOPIDOGREL, DOSAGEM:75 MG', 'CARVEDILOL, DOSAGEM:12,5 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CLOPIDOGREL, DOSAGEM:75 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:12,5 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:12,5 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:3,125 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARVEDILOL, DOSAGEM:6,25 MG', 'CARV ...

# %%
translated_texts
# Out:
# ['',
#  'Description\xa0CATMAT',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 12.5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 50 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CHLORTHALIDONE, DOSAGE: 25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CLOPIDOGREL, DOSAGEM:75 MG',
#  'CARVEDILOL, DOSAGEM:3,125 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG',
#  'CARVEDILOL, DOSAGEM:12,5 MG',
#  'CARVEDILOL, DOSAGEM:25 MG',
#  'CARVEDILOL, DOSAGEM:6,25 MG']

# %%
drug_names = []
concentrations = []

for item in translated_texts[2:]:
    parts = item.split(",", maxsplit = 1)
    drug_names.append(parts[0])
    if 'DOSAGE' or 'DOSAGEM' in parts[1]:
      concentrations.append(parts[1].split(":")[1])
    else:
      concentrations.append(None)



# Create DataFrame
df = pd.DataFrame({ 'Drug Original Name': drug_names,
    'Concentration': concentrations,
})

print(df)
# Out:
#     Drug Original Name Concentration
# 0           CARVEDILOL       6,25 MG
# 1           CARVEDILOL      3,125 MG
# 2           CARVEDILOL       12,5 MG
# 3           CARVEDILOL      3,125 MG
# 4           CARVEDILOL       12,5 MG
# ..                 ...           ...
# 950         CARVEDILOL      3,125 MG
# 951         CARVEDILOL       6,25 MG
# 952         CARVEDILOL       12,5 MG
# 953         CARVEDILOL         25 MG
# 954         CARVEDILOL       6,25 MG
#
# [955 rows x 2 columns]

# %%
'CHLORTHALIDONE, DOSAGE: 25 MG'.split(",", maxsplit = 1)
# Out:
# ['CHLORTHALIDONE', ' DOSAGE: 25 MG']

# %%
df.to_csv('BRACardio1-cleaned.csv')
