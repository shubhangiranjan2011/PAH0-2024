# %%
import pandas as pd
data = pd.read_csv('/content/BRAfludrocortisona.csv')
data
# Out:
#      Base de dados BPS                               Unnamed: 1  \
# 0        Dados do Item                                      NaN
# 1            Código BR                         Descrição CATMAT
# 2            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 3            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 4            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 5            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 6            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 7            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 8            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 9            BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 10           BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 11           BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 12           BR0272793  FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
#
#                    Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0                         NaN        NaN  Dados da Compra            NaN
# 1    Unidade de Fornecimento    Genérico  Registro Anvisa   Data Compra
# 2                  COMPRIMIDO        Não    1376401600011     10/05/2021
# 3                  COMPRIMIDO        Não    1376401600011     09/03/2021
# 4                  COMPRIMIDO        Não    Não Informado     10/11/2020
# 5                  COMPRIMIDO        Não    1376401600011     27/09/2021
# 6                  COMPRIMIDO        Não    1376401600011     08/07/2021
# 7                  COMPRIMIDO        Não    1376401600011     16/09/2021
# 8                  COMPRIMIDO        Não    1376401600011     10/08/2021
# 9                  COMPRIMIDO        Não    1376401600011     10/08/2021
# 10                 COMPRIMIDO        Não    1376401600011     18/10/2021
# 11                 COMPRIMIDO        Não    1376401600011     06/04/2021
# 12                 COMPRIMIDO        Não    1376401600011     05/07/2021
#
#                Unnamed: 6      Unnamed: 7   Unnamed: 8  \
# 0                     NaN             NaN          NaN
# 1    Modalidade da Compra   Data Inserção  Tipo Compra
# 2                  Pregão      20/07/2021            J
# 3                  Pregão      16/09/2021            A
# 4                  Pregão      04/12/2020            A
# 5   Dispensa de Licitação      07/10/2021            A
# 6                  Pregão      06/08/2021            J
# 7                  Pregão      04/10/2021            A
# 8                  Pregão      19/11/2021            A
# 9                  Pregão      26/11/2021            A
# 10                 Pregão      09/11/2021            A
# 11                 Pregão      20/08/2021            J
# 12                 Pregão      14/09/2021            A
#
#                                   Unnamed: 9  ...         Unnamed: 12  \
# 0             Dados do Fabricante Fornecedor  ...                 NaN
# 1                                 Fabricante  ...     CNPJ Fornecedor
# 2   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  07.752.236/0001-23
# 3   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  25.211.499/0001-07
# 4    BRISTOL-MYERS SQUIBB FARMACEUTICA LTDA.  ...  17.523.381/0001-96
# 5   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  02.433.631/0001-20
# 6   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  02.433.631/0001-20
# 7   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  02.433.631/0001-20
# 8   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  34.729.047/0001-02
# 9   ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  34.729.047/0001-02
# 10  ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  06.106.005/0001-80
# 11  ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  07.752.236/0001-23
# 12  ASPEN PHARMA INDUSTRIA FARMACEUTICA LTDA  ...  05.912.018/0001-83
#
#                                           Unnamed: 13         Unnamed: 14  \
# 0                                Dados da Instituição                 NaN
# 1                                    Nome Instituição    CNPJ Instituição
# 2                                 SECRETARIA DA SAUDE  87.958.625/0001-49
# 3                       SECRETARIA DE ESTADO DA SAUDE  02.529.964/0001-57
# 4                              MUNICIPIO DE ITAPERUCU  95.422.846/0001-26
# 5                       SECRETARIA DE ESTADO DA SAUDE  76.416.866/0001-40
# 6        FUNDO ESTADUAL DE SAUDE DO PARANA - FUNSAUDE  08.597.121/0001-74
# 7        FUNDO ESTADUAL DE SAUDE DO PARANA - FUNSAUDE  08.597.121/0001-74
# 8                       SECRETARIA DE ESTADO DA SAUDE  27.080.605/0001-96
# 9                       SECRETARIA DE ESTADO DA SAUDE  27.080.605/0001-96
# 10   CONSORCIO INTERMUNICIPAL CATARINENSE-CIMCATARINA  12.075.748/0001-32
# 11                                SECRETARIA DA SAUDE  87.958.625/0001-49
# 12  CONSORCIO INTERMUNICIPAL DE SAUDE DO VALE DO R...  07.242.772/0001-89
#
#               Unnamed: 15 Unnamed: 16          Unnamed: 17     Unnamed: 18  \
# 0                     NaN         NaN              Valores             NaN
# 1   Município Instituição          UF  Qtd Itens Comprados  Preço Unitário
# 2            PORTO ALEGRE          RS          420000,0000          0,4500
# 3                 GOIANIA          GO           45000,0000          1,4600
# 4               ITAPERUCU          PR             300,0000          1,4600
# 5                CURITIBA          PR           60000,0000          1,5800
# 6                CURITIBA          PR            2700,0000          1,5800
# 7                CURITIBA          PR          190000,0000          1,5800
# 8                 VITORIA          ES           16300,0000          1,5816
# 9                 VITORIA          ES           16300,0000          1,5816
# 10          FLORIANOPOLIS          SC           25620,0000          1,5816
# 11           PORTO ALEGRE          RS          240000,0000          1,6106
# 12                LAJEADO          RS            1000,0000          1,6520
#
#               Unnamed: 19       Unnamed: 20        Unnamed: 21
# 0                     NaN               NaN                NaN
# 1   CMED - Preço Regulado  Competência CMED   Média Ponderada
# 2                  1,5816           02/2022             1,6103
# 3                  1,5816           02/2022             1,5803
# 4                  0,0000               NaN             1,5803
# 5                  1,5816           02/2022             1,5803
# 6                  1,5816           02/2022             1,6103
# 7                  1,5816           02/2022             1,5803
# 8                  1,5816           02/2022             1,5803
# 9                  1,5816           02/2022             1,5803
# 10                 1,5816           02/2022             1,5803
# 11                 1,5816           02/2022             1,6103
# 12                 1,5816           02/2022             1,5803
#
# [13 rows x 22 columns]

# %%
rawdrugnames =  data[data.columns[1]]
rawdrugnames.tolist()
rawdrugnames
# Out:
# 0                                         NaN
# 1                            Descrição CATMAT
# 2     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 3     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 4     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 5     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 6     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 7     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 8     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 9     FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 10    FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 11    FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# 12    FLUDROCORTISONA ACETATO, DOSAGEM:0,1 MG
# Name: Unnamed: 1, dtype: object

# %%
pip install mtranslate==1.8
# Out:
# Collecting mtranslate==1.8
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3672 sha256=7b5f235a9ec5d25a74001310dc9d8c8ccee9bbfdd1ee6b5813d5af52a51556b9
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
from mtranslate import translate

def translate_text(text):
    if isinstance(text, str):
        try:
            # Encode text to bytes before translation
            text_bytes = text.encode('utf-8')
            translated = translate(text_bytes, 'en', 'auto')
            return translated
        except Exception as e:
            print(f"Translation failed: {e}")
            return "Translation failed"
    else:
        return ""


translated_texts = []
for text in rawdrugnames:
    translated_texts.append(translate_text(text))
print(translated_texts)
# Out:
# ['', 'Description\xa0CATMAT', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG', 'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG']

# %%
translated_texts
# Out:
# ['',
#  'Description\xa0CATMAT',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG',
#  'FLUDROCORTISONE ACETATE, DOSAGE: 0.1 MG']

# %%
drug_names = []
concentrations = []

for item in translated_texts[2:]:
    parts = item.split(",", maxsplit = 1)
    drug_names.append(parts[0])
    if 'DOSAGE'  in parts[1]:
      concentrations.append(parts[1].split(":")[1])
    else:
      concentrations.append(None)



# Create DataFrame
df = pd.DataFrame({ 'Drug Original Name': drug_names,
    'Dosage': concentrations,
})

print(df)
# Out:
#          Drug Original Name   Dosage
# 0   FLUDROCORTISONE ACETATE   0.1 MG
# 1   FLUDROCORTISONE ACETATE   0.1 MG
# 2   FLUDROCORTISONE ACETATE   0.1 MG
# 3   FLUDROCORTISONE ACETATE   0.1 MG
# 4   FLUDROCORTISONE ACETATE   0.1 MG
# 5   FLUDROCORTISONE ACETATE   0.1 MG
# 6   FLUDROCORTISONE ACETATE   0.1 MG
# 7   FLUDROCORTISONE ACETATE   0.1 MG
# 8   FLUDROCORTISONE ACETATE   0.1 MG
# 9   FLUDROCORTISONE ACETATE   0.1 MG
# 10  FLUDROCORTISONE ACETATE   0.1 MG

# %%
df.to_csv('BRAfludrocortisona-cleaned.csv')
