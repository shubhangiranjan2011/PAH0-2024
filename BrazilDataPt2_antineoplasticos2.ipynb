# %%
import pandas as pd
schema = pd.read_excel('/content/BRAantineoplasticos2 drugs_write_map.xlsx')

# %%
schema
# Out:
#    Unnamed: 0                      drugs english uppercase names  \
# 0           0  DOXORUBICIN HYDROCHLORIDE, CONCENTRATION: 2 MG...
# 1           1                FLUORURACIL, DOSAGE: 5%, USE: CREAM
# 2           2  DACARBAZINE, CONCENTRATION: 200 MG, USE: INJEC...
#
#                            Final paired catalog name  \
# 0  DOXORUBICIN 10 MG (HYDROCHLORIDE), POWDER FOR ...
# 1  INSULIN SOLUBLE 100 IU/ML, INJECTION, 10 ML VI...
# 2             DACARBAZINE 200MG, INJECTALBE SOLUTION
#
#             Final Drug Index    Presentation Form  Weight
# 0  DOXORUBICIN HYDROCHLORIDE  SOLUTION INJECTABLE    MG 2
# 1   FLUORURACIL DOSAGE CREAM                  NaN     NaN
# 2                DACARBAZINE           INJECTABLE  200 MG

# %%
data = pd.read_csv('/content/BRAantineoplasticos2.csv')

# %%
data
# Out:
#     Base de dados BPS                                         Unnamed: 1  \
# 0       Dados do Item                                                NaN
# 1           Código BR                                   Descrição CATMAT
# 2           BR0270438    DACARBAZINA, CONCENTRAÇÃO:200 MG, USO:INJETÁVEL
# 3           BR0276871                FLUORURACILA, DOSAGEM:5%, USO:CREME
# 4           BR0276871                FLUORURACILA, DOSAGEM:5%, USO:CREME
# 5           BR0276871                FLUORURACILA, DOSAGEM:5%, USO:CREME
# 6           BR0429928  DOXORRUBICINA CLORIDRATO, CONCENTRAÇÃO:2 MG/ML...
#
#                    Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0                         NaN        NaN  Dados da Compra            NaN
# 1    Unidade de Fornecimento    Genérico  Registro Anvisa   Data Compra
# 2               FRASCO-AMPOLA        Não    Não Informado     25/11/2020
# 3             BISNAGA 15,00 G        Não    1057500390011     21/12/2020
# 4             BISNAGA 15,00 G        Não    1057500390011     27/10/2020
# 5             BISNAGA 15,00 G        Não    1057500390011     31/08/2020
# 6  FRASCO 25,00 ML - GENÉRICO        Sim    1553700630021     10/06/2021
#
#              Unnamed: 6      Unnamed: 7   Unnamed: 8  \
# 0                   NaN             NaN          NaN
# 1  Modalidade da Compra   Data Inserção  Tipo Compra
# 2                Pregão      04/03/2021            A
# 3                Pregão      15/03/2021            A
# 4                Pregão      26/08/2021            A
# 5                Pregão      12/01/2021            A
# 6                Pregão      05/10/2021            A
#
#                              Unnamed: 9  ...         Unnamed: 12  \
# 0        Dados do Fabricante Fornecedor  ...                 NaN
# 1                            Fabricante  ...     CNPJ Fornecedor
# 2     LABORATORIO TEUTO BRASILEIRO S/A   ...  02.816.696/0001-54
# 3  VALEANT FARMACEUTICA DO BRASIL LTDA   ...  23.228.076/0001-74
# 4  VALEANT FARMACEUTICA DO BRASIL LTDA   ...  11.195.057/0001-00
# 5  VALEANT FARMACEUTICA DO BRASIL LTDA   ...  35.997.345/0001-46
# 6              ACCORD FARMACÊUTICA LTDA  ...  26.401.571/0001-21
#
#                           Unnamed: 13         Unnamed: 14  \
# 0                Dados da Instituição                 NaN
# 1                    Nome Instituição    CNPJ Instituição
# 2                MUNICIPIO DE PINHAIS  95.423.000/0001-00
# 3           MUNICIPIO DE SANTA HELENA  76.206.457/0001-19
# 4             MUNICIPIO DE MONTE ALTO  51.816.247/0001-11
# 5            FUNDO MUNICIPAL DE SAUDE  14.734.122/0001-16
# 6  UNIVERSIDADE FEDERAL DE UBERLANDIA  25.648.387/0001-18
#
#              Unnamed: 15 Unnamed: 16          Unnamed: 17     Unnamed: 18  \
# 0                    NaN         NaN              Valores             NaN
# 1  Município Instituição          UF  Qtd Itens Comprados  Preço Unitário
# 2                PINHAIS          PR               1,0000          0,0001
# 3           SANTA HELENA          PR             170,0000         12,8000
# 4             MONTE ALTO          SP              65,0000         15,8600
# 5     SAO ROQUE DO CANAA          ES             100,0000         17,5000
# 6             UBERLANDIA          MG            2280,0000         53,3300
#
#              Unnamed: 19       Unnamed: 20        Unnamed: 21
# 0                    NaN               NaN                NaN
# 1  CMED - Preço Regulado  Competência CMED   Média Ponderada
# 2                 0,0000               NaN             0,0001
# 3                 0,0000               NaN            16,8539
# 4                 0,0000               NaN            16,8539
# 5                 0,0000               NaN            16,8539
# 6               241,9900           02/2022            53,3300
#
# [7 rows x 22 columns]

# %%
rawdrugnames =  data[data.columns[1]]
rawdrugnames.tolist()
rawdrugnames
# Out:
# 0                                                  NaN
# 1                                     Descrição CATMAT
# 2      DACARBAZINA, CONCENTRAÇÃO:200 MG, USO:INJETÁVEL
# 3                  FLUORURACILA, DOSAGEM:5%, USO:CREME
# 4                  FLUORURACILA, DOSAGEM:5%, USO:CREME
# 5                  FLUORURACILA, DOSAGEM:5%, USO:CREME
# 6    DOXORRUBICINA CLORIDRATO, CONCENTRAÇÃO:2 MG/ML...
# Name: Unnamed: 1, dtype: object

# %%
pip install mtranslate==1.8
# Out:
# Collecting mtranslate==1.8
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3672 sha256=93299d144118836af6847ef010ed0937aa4da944e3dafcb1b2b31c19bee5eb24
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
from mtranslate import translate

def translate_text(text):
    if isinstance(text, str):
        try:
            # Encode text to bytes before translation
            text_bytes = text.encode('utf-8')
            translated = translate(text_bytes, 'en', 'auto')
            return translated
        except Exception as e:
            print(f"Translation failed: {e}")
            return "Translation failed"
    else:
        return ""


translated_texts = []
for text in rawdrugnames:
    translated_texts.append(translate_text(text))
print(translated_texts)
# Out:
# ['', 'Description\xa0CATMAT', 'DACARBAZINE, CONCENTRATION: 200 MG, USE: INJECTABLE', 'FLUORURACILA, DOSAGE: 5%, USE: CREAM', 'FLUORURACILA, DOSAGE: 5%, USE: CREAM', 'FLUORURACILA, DOSAGE: 5%, USE: CREAM', 'DOXORUBICIN HYCLORIDATE, CONCENTRATION: 2 MG/ML, PHARMACEUTICAL FORM: INJECTABLE SOLUTION']

# %%
drug_names = []
concentrations = []
pharmaceutical_forms = []

for item in translated_texts:
    parts = item.split(", ")
    drug_names.append(parts[0])
    if len(parts) > 1:
        if 'CONCENTRATION' in parts[1]:
            concentrations.append(parts[1].split(": ")[1])
            if len(parts) > 2:
                pharmaceutical_forms.append(parts[2].split(": ")[1])
            else:
                pharmaceutical_forms.append(None)
        else:
          concentrations.append(parts[1].split(": ")[1])
          pharmaceutical_forms.append(None)
    else:
        concentrations.append(None)
        pharmaceutical_forms.append(None)

# Create DataFrame
df = pd.DataFrame({ 'Drug Original Name': drug_names,
    'Concentration': concentrations,
    'Pharmaceutical Form': pharmaceutical_forms
})

print(df)
# Out:
#         Drug Original Name Concentration  Pharmaceutical Form
# 0                                   None                 None
# 1       Description CATMAT          None                 None
# 2              DACARBAZINE        200 MG           INJECTABLE
# 3             FLUORURACILA            5%                 None
# 4             FLUORURACILA            5%                 None
# 5             FLUORURACILA            5%                 None
# 6  DOXORUBICIN HYCLORIDATE       2 MG/ML  INJECTABLE SOLUTION

# %%
final_df = df[2:]
final_df
final_df.to_csv('BRAantineoplasticos2-cleaned.csv')
