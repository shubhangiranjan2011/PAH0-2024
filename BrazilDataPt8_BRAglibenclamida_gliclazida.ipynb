# %%
import pandas as pd
data = pd.read_csv('/content/BRAglibenclamida-gliclazida.csv')
data
# Out:
#       Base de dados BPS                                         Unnamed: 1  \
# 0         Dados do Item                                                NaN
# 1             Código BR                                   Descrição CATMAT
# 2             BR0267671                        GLIBENCLAMIDA, DOSAGEM:5 MG
# 3             BR0267671                        GLIBENCLAMIDA, DOSAGEM:5 MG
# 4             BR0267671                        GLIBENCLAMIDA, DOSAGEM:5 MG
# ..                  ...                                                ...
# 422           BR0442754  GLICLAZIDA, CONCENTRAÇÃO:30 MG, FORMA FARMACÊU...
# 423           BR0267671                        GLIBENCLAMIDA, DOSAGEM:5 MG
# 424           BR0442754  GLICLAZIDA, CONCENTRAÇÃO:30 MG, FORMA FARMACÊU...
# 425           BR0442755  GLICLAZIDA, CONCENTRAÇÃO:60 MG, FORMA FARMACÊU...
# 426           BR0442754  GLICLAZIDA, CONCENTRAÇÃO:30 MG, FORMA FARMACÊU...
#
#                     Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0                          NaN        NaN  Dados da Compra            NaN
# 1     Unidade de Fornecimento    Genérico  Registro Anvisa   Data Compra
# 2                   COMPRIMIDO        Não    1091700640011     11/10/2021
# 3                   COMPRIMIDO        Não    1091700640011     26/02/2021
# 4                   COMPRIMIDO        Não    Não Informado     26/01/2022
# ..                         ...        ...              ...            ...
# 422                 COMPRIMIDO        Não    Não Informado     24/09/2020
# 423                 COMPRIMIDO        Não    1103901510031     31/03/2021
# 424                 COMPRIMIDO        Não    Não Informado     19/07/2021
# 425                 COMPRIMIDO        Não    Não Informado     24/09/2020
# 426      COMPRIMIDO - GENÉRICO        Sim    1235202690025     10/11/2020
#
#                 Unnamed: 6      Unnamed: 7   Unnamed: 8  \
# 0                      NaN             NaN          NaN
# 1     Modalidade da Compra   Data Inserção  Tipo Compra
# 2                   Pregão      22/11/2021            A
# 3                   Pregão      03/03/2021            A
# 4                   Pregão      14/02/2022            A
# ..                     ...             ...          ...
# 422                 Pregão      26/05/2021            A
# 423                 Pregão      29/04/2021            A
# 424  Dispensa de Licitação      23/08/2021            A
# 425                 Pregão      26/05/2021            A
# 426                 Pregão      01/03/2021            A
#
#                                    Unnamed: 9  ...         Unnamed: 12  \
# 0              Dados do Fabricante Fornecedor  ...                 NaN
# 1                                  Fabricante  ...     CNPJ Fornecedor
# 2     MEDQUIMICA INDUSTRIA FARMACEUTICA LTDA   ...  10.436.883/0001-30
# 3     MEDQUIMICA INDUSTRIA FARMACEUTICA LTDA   ...  81.706.251/0001-98
# 4    MEDQUIMICA INDUSTRIA FARMACEUTICA LTDA.   ...  81.706.251/0001-98
# ..                                        ...  ...                 ...
# 422                                   EMS S/A  ...  16.970.999/0001-31
# 423      FUNDACAO PARA O REMEDIO POPULAR FURP  ...  03.894.963/0001-74
# 424                                   EMS S/A  ...  28.093.678/0001-85
# 425                                   EMS S/A  ...  16.970.999/0001-31
# 426                 RANBAXY FARMACEUTICA LTDA  ...  21.681.325/0001-57
#
#                                            Unnamed: 13         Unnamed: 14  \
# 0                                 Dados da Instituição                 NaN
# 1                                     Nome Instituição    CNPJ Instituição
# 2                             FUNDO MUNICIPAL DE SAUDE  11.594.727/0001-60
# 3            FUNDO MUNICIPAL DE SAUDE DE DOIS VIZINHOS  08.889.455/0001-11
# 4     FUNDO MUNICIPAL DE SAUDE DO MUNICIPIO DE GOIOERE  09.298.629/0001-34
# ..                                                 ...                 ...
# 422             FUNDO  MUNICIPAL  DE  SAUDE DE  MARABA  18.478.187/0001-07
# 423  MUNICIPIO DE NAZARE DO PIAUI - SECRETARIA DE S...  01.825.779/0001-47
# 424               FUNDO MUNICIPAL DE SAUDE DE UMUARAMA  08.931.506/0001-26
# 425             FUNDO  MUNICIPAL  DE  SAUDE DE  MARABA  18.478.187/0001-07
# 426                          MUNICIPIO DE DOURADOQUARA  18.158.261/0001-08
#
#                Unnamed: 15 Unnamed: 16          Unnamed: 17     Unnamed: 18  \
# 0                      NaN         NaN              Valores             NaN
# 1    Município Instituição          UF  Qtd Itens Comprados  Preço Unitário
# 2             MAR VERMELHO          AL           80000,0000          0,0003
# 3            DOIS VIZINHOS          PR           10000,0000          0,0180
# 4                  GOIOERE          PR            1000,0000          0,0200
# ..                     ...         ...                  ...             ...
# 422                 MARABA          PA             200,0000         10,3600
# 423        NAZARE DO PIAUI          PI             100,0000         27,7500
# 424               UMUARAMA          PR           15000,0000         29,0000
# 425                 MARABA          PA             400,0000         46,2000
# 426           DOURADOQUARA          MG              12,0000         64,6500
#
#                Unnamed: 19       Unnamed: 20        Unnamed: 21
# 0                      NaN               NaN                NaN
# 1    CMED - Preço Regulado  Competência CMED   Média Ponderada
# 2                   0,2073           02/2022             0,0286
# 3                   0,2073           02/2022             0,0286
# 4                   0,0000               NaN             0,0286
# ..                     ...               ...                ...
# 422                 0,0000               NaN             0,1379
# 423                 0,0867           02/2022             0,0286
# 424                 0,0000               NaN             0,1379
# 425                 0,0000               NaN             0,2849
# 426                 0,6040           02/2022             0,1379
#
# [427 rows x 22 columns]

# %%
rawdrugnames =  data[data.columns[1]]
rawdrugnames.tolist()
rawdrugnames
# Out:
# 0                                                    NaN
# 1                                       Descrição CATMAT
# 2                            GLIBENCLAMIDA, DOSAGEM:5 MG
# 3                            GLIBENCLAMIDA, DOSAGEM:5 MG
# 4                            GLIBENCLAMIDA, DOSAGEM:5 MG
#                              ...
# 422    GLICLAZIDA, CONCENTRAÇÃO:30 MG, FORMA FARMACÊU...
# 423                          GLIBENCLAMIDA, DOSAGEM:5 MG
# 424    GLICLAZIDA, CONCENTRAÇÃO:30 MG, FORMA FARMACÊU...
# 425    GLICLAZIDA, CONCENTRAÇÃO:60 MG, FORMA FARMACÊU...
# 426    GLICLAZIDA, CONCENTRAÇÃO:30 MG, FORMA FARMACÊU...
# Name: Unnamed: 1, Length: 427, dtype: object

# %%
pip install mtranslate==1.8
# Out:
# Collecting mtranslate==1.8
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3672 sha256=c809a563e6acaf2819cf51180fd64ef454c4c900eb146de8f09ef134506b1900
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
from mtranslate import translate

def translate_text(text):
    if isinstance(text, str):
        try:
            # Encode text to bytes before translation
            text_bytes = text.encode('utf-8')
            translated = translate(text_bytes, 'en', 'auto')
            return translated
        except Exception as e:
            print(f"Translation failed: {e}")
            return "Translation failed"
    else:
        return ""


translated_texts = []
for text in rawdrugnames:
    translated_texts.append(translate_text(text))
print(translated_texts)
# Out:
# ['', 'Description\xa0CATMAT', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOSAGE: 5 MG', 'GLIBENCLAMIDE, DOS ...

# %%
translated_texts
# Out:
# ['',
#  'Description\xa0CATMAT',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 80 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 80 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLIBENCLAMIDE, DOSAGE: 5 MG',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 60 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE',
#  'GLICLAZIDE, CONCENTRATION: 30 MG, PHARMACEUTICAL FORM: PROLONGED RELEASE']

# %%
drug_names = []
concentrations = []
pharmaceutical_forms = []

for item in translated_texts[2:]:
    parts = item.split(", ")
    drug_names.append(parts[0])
    if len(parts) > 1:
        if 'CONCENTRATION' or 'DOSAGE' in parts[1]:
            concentrations.append(parts[1].split(": ")[1])
            if len(parts) > 2:
                pharmaceutical_forms.append(parts[2].split(": ")[1])
            else:
                pharmaceutical_forms.append(None)
        else:
          concentrations.append(parts[1].split(": ")[1])
          pharmaceutical_forms.append(None)
    else:
        concentrations.append(None)
        pharmaceutical_forms.append(None)

# Create DataFrame
df = pd.DataFrame({ 'Drug Original Name': drug_names,
    'Concentration': concentrations,
    'Pharmaceutical Form': pharmaceutical_forms
})

print(df)
# Out:
#     Drug Original Name Concentration Pharmaceutical Form
# 0        GLIBENCLAMIDE          5 MG                None
# 1        GLIBENCLAMIDE          5 MG                None
# 2        GLIBENCLAMIDE          5 MG                None
# 3        GLIBENCLAMIDE          5 MG                None
# 4        GLIBENCLAMIDE          5 MG                None
# ..                 ...           ...                 ...
# 420         GLICLAZIDE         30 MG   PROLONGED RELEASE
# 421      GLIBENCLAMIDE          5 MG                None
# 422         GLICLAZIDE         30 MG   PROLONGED RELEASE
# 423         GLICLAZIDE         60 MG   PROLONGED RELEASE
# 424         GLICLAZIDE         30 MG   PROLONGED RELEASE
#
# [425 rows x 3 columns]

# %%
df.to_csv('BRAglibenclamida-gliclazida-cleaned.csv')
