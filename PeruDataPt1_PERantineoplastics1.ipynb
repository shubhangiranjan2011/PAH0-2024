# %%
# !pip install openpyxl
import openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
data = pd.read_excel('/content/PERantineoplastics1.xlsx')
data
# Out:
#      Búsqueda por Proveedor      Unnamed: 1 Unnamed: 2          Unnamed: 3  \
# 0                       NaN             NaN        NaN                 NaN
# 1                       NaN             NaN        NaN                 NaN
# 2               RazonSocial  Código Entidad    Entidad  Código Disa/Diresa
# 3                REFASA SAC               7     MINDEF                 123
# 4                REFASA SAC               7     MINDEF                 124
# ...                     ...             ...        ...                 ...
# 1786           MEDIFARMA SA               1      MINSA                   4
# 1787           MEDIFARMA SA               1      MINSA                  11
# 1788           MEDIFARMA SA               1      MINSA                  11
# 1789           MEDIFARMA SA               1      MINSA                 130
# 1790           MEDIFARMA SA               1      MINSA                  36
#
#                 Unnamed: 4               Unnamed: 5  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2          Establecimiento  Código Unidad Ejecutora
# 3        EJERCITO DEL PERU                    1001B
# 4     FUERZA AREA DEL PERU                      472
# ...                    ...                      ...
# 1786       GERESA AREQUIPA                      767
# 1787          DIRESA CUSCO                     1169
# 1788          DIRESA CUSCO                     1130
# 1789       MINSA - CENARES                     9999
# 1790                 MINSA                     1670
#
#                                              Unnamed: 6  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                      Punto de Entrega
# 3                                     EJERCITO DEL PERÚ
# 4                                 FUERZA AÉREA DEL PERÚ
# ...                                                 ...
# 1786                  HOSPITAL REGIONAL HONORIO DELGADO
# 1787                      HOSPITAL APOYO ANTONIO LORENA
# 1788                        HOSPITAL REGIONAL DEL CUSCO
# 1789  CENTRO NACIONAL DE ABASTECIMIENTO DE RECURSOS ...
# 1790          HOSPITAL DE EMERGENCIAS VILLA EL SALVADOR
#
#                   Unnamed: 7       Unnamed: 8                Unnamed: 9  \
# 0                        NaN              NaN                       NaN
# 1                        NaN              NaN                       NaN
# 2     Identificación Proceso  Código Producto                  Producto
# 3          LP SIP N 12  2012            04665  MERCAPTOPURINA 50 MG TAB
# 4          LP SIP N 12  2012            04665  MERCAPTOPURINA 50 MG TAB
# ...                      ...              ...                       ...
# 1786      SIE SIP N 13  2020            04670  MESNA 100 MG/ML INY 4 ML
# 1787      SIE SIP N 13  2020            04670  MESNA 100 MG/ML INY 4 ML
# 1788      SIE SIP N 13  2020            04670  MESNA 100 MG/ML INY 4 ML
# 1789      SIE SIP N 13  2020            04670  MESNA 100 MG/ML INY 4 ML
# 1790      SIE SIP N 13  2020            04670  MESNA 100 MG/ML INY 4 ML
#
#      Unnamed: 10                  Unnamed: 11              Unnamed: 12  \
# 0            NaN                          NaN                      NaN
# 1            NaN                          NaN                      NaN
# 2       Cantidad  Precio Unitario Referencial  Monto Total Referencial
# 3           3700                       0.4841                  1791.17
# 4            100                       0.4841                    48.41
# ...          ...                          ...                      ...
# 1786         100                       3.2091                   320.91
# 1787        1000                       3.2091                   3209.1
# 1788         400                       3.2091                  1283.64
# 1789       10000                       3.2091                    32091
# 1790          50                       3.2091                  160.455
#
#                    Unnamed: 13           Unnamed: 14 Unnamed: 15
# 0                          NaN                   NaN         NaN
# 1                          NaN                   NaN         NaN
# 2     Precio Unitario Ofertado  Monto Total Ofertado        Pais
# 3                     0.425948           1576.007973         NaN
# 4                     0.425948              42.59481         NaN
# ...                        ...                   ...         ...
# 1786                  3.247121             324.71206         NaN
# 1787                  3.247121           3247.120599         NaN
# 1788                  3.247121           1298.848239         NaN
# 1789                  3.247121          32471.205986         NaN
# 1790                  3.247121             162.35603         NaN
#
# [1791 rows x 16 columns]

# %%
rawdrugnames =  data[data.columns[9]]
rawdrugnames.tolist()
rawdrugnames
# Out:
# 0                            NaN
# 1                            NaN
# 2                       Producto
# 3       MERCAPTOPURINA 50 MG TAB
# 4       MERCAPTOPURINA 50 MG TAB
#                   ...
# 1786    MESNA 100 MG/ML INY 4 ML
# 1787    MESNA 100 MG/ML INY 4 ML
# 1788    MESNA 100 MG/ML INY 4 ML
# 1789    MESNA 100 MG/ML INY 4 ML
# 1790    MESNA 100 MG/ML INY 4 ML
# Name: Unnamed: 9, Length: 1791, dtype: object

# %%
pip install mtranslate==1.8
# Out:
# Collecting mtranslate==1.8
#   Downloading mtranslate-1.8.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mtranslate
#   Building wheel for mtranslate (setup.py) ... done
#   Created wheel for mtranslate: filename=mtranslate-1.8-py3-none-any.whl size=3672 sha256=3adf69c258814d59eb05e459882ec641a24d1c6e2045f2a7c5f69bcb03f4aa88
#   Stored in directory: /root/.cache/pip/wheels/c2/04/15/d7654c2c4a9a52e09922967593f3278fed66059be65ca671ea
# Successfully built mtranslate
# Installing collected packages: mtranslate
# Successfully installed mtranslate-1.8

# %%
from mtranslate import translate

def translate_text(text):
    if isinstance(text, str):
        try:
            # Encode text to bytes before translation
            text_bytes = text.encode('utf-8')
            translated = translate(text_bytes, 'en', 'auto')
            return translated
        except Exception as e:
            print(f"Translation failed: {e}")
            return "Translation failed"
    else:
        return ""


translated_texts = []
for text in rawdrugnames:
    translated_texts.append(translate_text(text))
print(translated_texts)
# Out:
# Translation failed: HTTP Error 500: Internal Server Error
# Translation failed: HTTP Error 500: Internal Server Error
# Translation failed: HTTP Error 500: Internal Server Error
# Translation failed: HTTP Error 500: Internal Server Error
# ['', '', 'Product', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'MERCAPTOPURINA 50 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'TAMOXIFENO CITRATE 20 MG TAB', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 25 MG/ML INY 2 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'SODIUM METHOTREXATE 500 MG INY 20 ML', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'FLUOROURACILO 500 MG INY', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'MESNA 100 MG/ML INY 4 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY 1 ML', 'VINCRISTINA SULFATO 1 MG/ML INY  ...

# %%
translated_texts[:-50]
# Out:
# ['',
#  '',
#  'Product',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'MERCAPTOPURINA 50 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'VINCRISTINA SULFATO 1 MG/ML INY 1 ML',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 100 MG INY 17 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'Translation failed',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'Translation failed',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'IFOSFAMIDA 1 G INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'Translation failed',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'SODIUM METHOTREXATE 25 MG/ML INY 2 ML',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'FLUOROURACILO 500 MG INY',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'CAPECITABINA 500 MG TAB',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'VINCRISTINE SULFATO 1 MG',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'FLUOROURACILO 50 MG/ML INY 5 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'PACLITAXEL 30 MG INY 5 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 100 MG/10 ML INY 10 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'Translation failed',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'RITUXIMAB 500 MG/50 ML INY 50 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'MESNA 100 MG/ML INY 4 ML',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 2.5 MG TAB',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'SODIUM METHOTREXATE 500 MG INY 20 ML',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 100 MG/16.7 ML  INY',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'PACLITAXEL 300 MG INY 50ML',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  'TAMOXIFENO CITRATE 20 MG TAB',
#  ...]

# %%
rawdrugnames
# Out:
# 0                            NaN
# 1                            NaN
# 2                       Producto
# 3       MERCAPTOPURINA 50 MG TAB
# 4       MERCAPTOPURINA 50 MG TAB
#                   ...
# 1786    MESNA 100 MG/ML INY 4 ML
# 1787    MESNA 100 MG/ML INY 4 ML
# 1788    MESNA 100 MG/ML INY 4 ML
# 1789    MESNA 100 MG/ML INY 4 ML
# 1790    MESNA 100 MG/ML INY 4 ML
# Name: Unnamed: 9, Length: 1791, dtype: object

# %%
drug_names = []
concentrations = []


for row in translated_texts[3:]:
  # Find the first index of a numeric character
  first_numeric_index = next((i for i, char in enumerate(row) if char.isdigit()), None)

  # Check if there are numeric characters
  if first_numeric_index is not None:
    # Extract drug name based on the index
    drug_name = row[:first_numeric_index]
    # Extract composition including numeric characters
    composition = row[first_numeric_index:]


    # Append the extracted values to the lists
    drug_names.append(drug_name)
    concentrations.append(composition)

# Create DataFrame
df = pd.DataFrame({ 'Drug Original Name': drug_names,
    'Concentration': concentrations
})

print(df)
# Out:
#      Drug Original Name       Concentration
# 0       MERCAPTOPURINA            50 MG TAB
# 1       MERCAPTOPURINA            50 MG TAB
# 2       MERCAPTOPURINA            50 MG TAB
# 3       MERCAPTOPURINA            50 MG TAB
# 4       MERCAPTOPURINA            50 MG TAB
# ...                 ...                 ...
# 1779             MESNA   100 MG/ML INY 4 ML
# 1780             MESNA   100 MG/ML INY 4 ML
# 1781             MESNA   100 MG/ML INY 4 ML
# 1782             MESNA   100 MG/ML INY 4 ML
# 1783             MESNA   100 MG/ML INY 4 ML
#
# [1784 rows x 2 columns]

# %%
df.to_csv('PERantineoplastics1-cleaned.csv')
